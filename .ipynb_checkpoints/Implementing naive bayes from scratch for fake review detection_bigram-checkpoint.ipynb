# %%
import nltk
from nltk.tokenize import treebank
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
import math
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import random
from sklearn.feature_extraction.text import CountVectorizer
import string
import re
ngram_vectorizer = CountVectorizer(binary=True, ngram_range=(1, 2))

# %%
stopword = set(stopwords.words('english'))

# %%
dataset = pd.read_csv('deceptive-opinion.csv')
def clean_text(text):
    text_lc = "".join([word.lower() for word in text ]) # remove puntuation
    text_rc = re.sub('[0-9]+', '', text_lc)
    tokens = re.split('\W+', text_rc)    # tokenization
    text = [word for word in tokens if word not in stopword ]  # remove stopwords and stemming
    return text
def listtostr(s):
    str1=" "
    return (str1.join(s))
dataset['data_cleaned'] = dataset['text'].apply(lambda x: clean_text(x))
dataset['data_cleaned_str'] = dataset['data_cleaned'].apply(lambda x: listtostr(x))
dataset
# Out:
#       deceptive             hotel  polarity       source  \
# 0      truthful            conrad  positive  TripAdvisor
# 1      truthful             hyatt  positive  TripAdvisor
# 2      truthful             hyatt  positive  TripAdvisor
# 3      truthful              omni  positive  TripAdvisor
# 4      truthful             hyatt  positive  TripAdvisor
# ...         ...               ...       ...          ...
# 1595  deceptive  intercontinental  negative        MTurk
# 1596  deceptive            amalfi  negative        MTurk
# 1597  deceptive  intercontinental  negative        MTurk
# 1598  deceptive            palmer  negative        MTurk
# 1599  deceptive            amalfi  negative        MTurk
#
#                                                    text  \
# 0     We stayed for a one night getaway with family ...
# 1     Triple A rate with upgrade to view room was le...
# 2     This comes a little late as I'm finally catchi...
# 3     The Omni Chicago really delivers on all fronts...
# 4     I asked for a high floor away from the elevato...
# ...                                                 ...
# 1595  Problems started when I booked the InterContin...
# 1596  The Amalfi Hotel has a beautiful website and i...
# 1597  The Intercontinental Chicago Magnificent Mile ...
# 1598  The Palmer House Hilton, while it looks good i...
# 1599  As a former Chicagoan, I'm appalled at the Ama...
#
#                                            data_cleaned  \
# 0     [stayed, one, night, getaway, family, thursday...
# 1     [triple, rate, upgrade, view, room, less, also...
# 2     [comes, little, late, finally, catching, revie...
# 3     [omni, chicago, really, delivers, fronts, spac...
# 4     [asked, high, floor, away, elevator, got, room...
# ...                                                 ...
# 1595  [problems, started, booked, intercontinental, ...
# 1596  [amalfi, hotel, beautiful, website, interior, ...
# 1597  [intercontinental, chicago, magnificent, mile,...
# 1598  [palmer, house, hilton, looks, good, pictures,...
# 1599  [former, chicagoan, appalled, amalfi, hotel, c...
#
#                                        data_cleaned_str
# 0     stayed one night getaway family thursday tripl...
# 1     triple rate upgrade view room less also includ...
# 2     comes little late finally catching reviews pas...
# 3     omni chicago really delivers fronts spaciousne...
# 4     asked high floor away elevator got room pleasa...
# ...                                                 ...
# 1595  problems started booked intercontinental chica...
# 1596  amalfi hotel beautiful website interior decora...
# 1597  intercontinental chicago magnificent mile outs...
# 1598  palmer house hilton looks good pictures outsid...
# 1599  former chicagoan appalled amalfi hotel chicago...
#
# [1600 rows x 7 columns]

# %%
truthful_prior_log_prob = math.log((list(dataset['deceptive']).count("truthful"))/len(dataset))
deceptive_prior_log_prob = math.log((list(dataset['deceptive']).count("deceptive"))/len(dataset))

# %%
def train_test_split(df,test_size):
    if isinstance(test_size,float):
        test_size = round(test_size * len(df))
        
    if(test_size > len(df)):
        return 0, df

    indices = df.index.tolist()
    test_indices = random.sample(population=indices,k = test_size)

    test_df = df.loc[test_indices]
    train_df = df.drop(test_indices)
    
    return train_df, test_df


def bigrams_convert(text):
    word = re.split('\W+', text)
    number_of_words = len(word)
    list_of_bigrams = []

    list_of_bigrams=[word[i] + ' ' + word[i+1] for i in range(number_of_words-1)]
    
    return list_of_bigrams
        
dataset['data_bigrams'] = dataset['data_cleaned_str'].apply(lambda x: bigrams_convert(x))

train_df,test_df = train_test_split(dataset,0.3)
        
new=train_df['data_bigrams']

test_df
# Out:
#       deceptive             hotel  polarity       source  \
# 312    truthful            hilton  positive  TripAdvisor
# 1195   truthful  intercontinental  negative          Web
# 571   deceptive           affinia  positive        MTurk
# 526   deceptive         swissotel  positive        MTurk
# 1104   truthful           sofitel  negative          Web
# ...         ...               ...       ...          ...
# 847    truthful              omni  negative          Web
# 783   deceptive           allegro  positive        MTurk
# 217    truthful        ambassador  positive  TripAdvisor
# 1416  deceptive           talbott  negative        MTurk
# 1451  deceptive            monaco  negative        MTurk
#
#                                                    text  \
# 312   We stayed here from Nov. 30 to Dec 2 and had a...
# 1195  We booked directly with the Intercontinental--...
# 571   The Affinia Hotel is beautiful! It's in a grea...
# 526   This is the hotel for the discriminating busin...
# 1104  October 3rd, 2007 My wife and I stayed at The ...
# ...                                                 ...
# 847   The Omni was chosen for it's location whichwor...
# 783   I have to admit, I was a little leery about vi...
# 217   We stayed at the AE for two nights for a three...
# 1416  WARNING! My stay at the Talbott Hotel will go ...
# 1451  I stayed at the Monaco-Chicago back in April. ...
#
#                                            data_cleaned  \
# 312   [stayed, nov, dec, wonderful, time, hotel, bea...
# 1195  [booked, directly, intercontinental, special, ...
# 571   [affinia, hotel, beautiful, great, location, s...
# 526   [hotel, discriminating, business, traveler, of...
# 1104  [october, rd, wife, stayed, sofitel, toward, e...
# ...                                                 ...
# 847   [omni, chosen, location, whichworked, perfectl...
# 783   [admit, little, leery, visiting, chicago, due,...
# 217   [stayed, ae, two, nights, three, generation, g...
# 1416  [warning, stay, talbott, hotel, go, history, o...
# 1451  [stayed, monaco, chicago, back, april, town, b...
#
#                                        data_cleaned_str  \
# 312   stayed nov dec wonderful time hotel beautiful ...
# 1195  booked directly intercontinental special room ...
# 571   affinia hotel beautiful great location service...
# 526   hotel discriminating business traveler offers ...
# 1104  october rd wife stayed sofitel toward end sept...
# ...                                                 ...
# 847   omni chosen location whichworked perfectly bed...
# 783   admit little leery visiting chicago due mild a...
# 217   stayed ae two nights three generation girls we...
# 1416  warning stay talbott hotel go history one wors...
# 1451  stayed monaco chicago back april town business...
#
#                                            data_bigrams
# 312   [stayed nov, nov dec, dec wonderful, wonderful...
# 1195  [booked directly, directly intercontinental, i...
# 571   [affinia hotel, hotel beautiful, beautiful gre...
# 526   [hotel discriminating, discriminating business...
# 1104  [october rd, rd wife, wife stayed, stayed sofi...
# ...                                                 ...
# 847   [omni chosen, chosen location, location whichw...
# 783   [admit little, little leery, leery visiting, v...
# 217   [stayed ae, ae two, two nights, nights three, ...
# 1416  [warning stay, stay talbott, talbott hotel, ho...
# 1451  [stayed monaco, monaco chicago, chicago back, ...
#
# [480 rows x 8 columns]

# %%
voc = {}
truthful_token_count = {} #how many occurances of each word for truthful class
deceptive_token_count = {}

for i in range(len(train_df)):
    #review = list(train_df['data_cleaned_str'])[i]
   # words = word_tokenize(review)
    new_words =train_df['data_bigrams']
    #new=[]
    #new.append(new_words)
    new_words = [y for x in new_words for y in x]
   
    

    for word in new_words[i]:
        if word not in voc:
            voc[word] = 1
        else:
            voc[word] += 1
        if list(train_df['deceptive'])[i] == "truthful":
            if word not in truthful_token_count:
                truthful_token_count[word] = 1
            else:
                truthful_token_count[word] += 1
            if word not in deceptive_token_count:
                deceptive_token_count[word] = 0
        else:
            if word not in deceptive_token_count:
                deceptive_token_count[word] = 1
            else:
                deceptive_token_count[word] += 1
            if word not in truthful_token_count:
                truthful_token_count[word] = 0
                
new_words
# Out:
# ['stayed one',
#  'one night',
#  'night getaway',
#  'getaway family',
#  'family thursday',
#  'thursday triple',
#  'triple aaa',
#  'aaa rate',
#  'rate steal',
#  'steal th',
#  'th floor',
#  'floor room',
#  'room complete',
#  'complete plasma',
#  'plasma tv',
#  'tv bose',
#  'bose stereo',
#  'stereo voss',
#  'voss evian',
#  'evian water',
#  'water gorgeous',
#  'gorgeous bathroom',
#  'bathroom tub',
#  'tub fine',
#  'fine us',
#  'us concierge',
#  'concierge helpful',
#  'helpful cannot',
#  'cannot beat',
#  'beat location',
#  'location flaw',
#  'flaw breakfast',
#  'breakfast pricey',
#  'pricey service',
#  'service slow',
#  'slow hours',
#  'hours four',
#  'four kids',
#  'kids four',
#  'four adults',
#  'adults friday',
#  'friday morning',
#  'morning even',
#  'even though',
#  'though two',
#  'two tables',
#  'tables restaurant',
#  'restaurant food',
#  'food good',
#  'good worth',
#  'worth wait',
#  'wait would',
#  'would return',
#  'return heartbeat',
#  'heartbeat gem',
#  'gem chicago',
#  'chicago ',
#  'comes little',
#  'little late',
#  'late finally',
#  'finally catching',
#  'catching reviews',
#  'reviews past',
#  'past several',
#  'several months',
#  'months dear',
#  'dear friend',
#  'friend stayed',
#  'stayed hyatt',
#  'hyatt regency',
#  'regency late',
#  'late october',
#  'october one',
#  'one night',
#  'night visiting',
#  'visiting friend',
#  'friend husband',
#  'husband town',
#  'town hotel',
#  'hotel perfect',
#  'perfect imo',
#  'imo easy',
#  'easy check',
#  'check check',
#  'check lovely',
#  'lovely clean',
#  'clean comfortable',
#  'comfortable rooms',
#  'rooms great',
#  'great views',
#  'views city',
#  'city know',
#  'know area',
#  'area pretty',
#  'pretty well',
#  'well convenient',
#  'convenient many',
#  'many downtown',
#  'downtown chicago',
#  'chicago attractions',
#  'attractions dinner',
#  'dinner went',
#  'went clubing',
#  'clubing friends',
#  'friends around',
#  'around division',
#  'division st',
#  'st problems',
#  'problems getting',
#  'getting cabs',
#  'cabs back',
#  'back forth',
#  'forth hyatt',
#  'hyatt even',
#  'even public',
#  'public transportation',
#  'transportation right',
#  'right near',
#  'near bother',
#  'bother since',
#  'since needed',
#  'needed cabs',
#  'cabs hotel',
#  'hotel parking',
#  'parking usual',
#  'usual chicago',
#  'chicago expensive',
#  'expensive able',
#  'able get',
#  'get car',
#  'car quickly',
#  'quickly however',
#  'however left',
#  'left sunday',
#  'sunday morning',
#  'morning exactly',
#  'exactly high',
#  'high traffic',
#  'traffic time',
#  'time although',
#  'although bears',
#  'bears homegame',
#  'homegame day',
#  'day bit',
#  'bit busier',
#  'busier usual',
#  'usual would',
#  'would think',
#  'think problems',
#  'problems best',
#  'best part',
#  'part got',
#  'got rate',
#  'rate hotwire',
#  'hotwire downright',
#  'downright steal',
#  'steal area',
#  'area chicago',
#  'chicago quality',
#  'quality hotel',
#  'hotel ',
#  'omni chicago',
#  'chicago really',
#  'really delivers',
#  'delivers fronts',
#  'fronts spaciousness',
#  'spaciousness rooms',
#  'rooms helpful',
#  'helpful staff',
#  'staff prized',
#  'prized location',
#  'location michigan',
#  'michigan avenue',
#  'avenue address',
#  'address chicago',
#  'chicago requires',
#  'requires high',
#  'high level',
#  'level quality',
#  'quality omni',
#  'omni delivers',
#  'delivers check',
#  'check whole',
#  'whole group',
#  'group people',
#  'people minutes',
#  'minutes staff',
#  'staff plentiful',
#  'plentiful recommendations',
#  'recommendations dining',
#  'dining events',
#  'events rooms',
#  'rooms largest',
#  'largest find',
#  'find price',
#  'price range',
#  'range chicago',
#  'chicago even',
#  'even standard',
#  'standard room',
#  'room separate',
#  'separate living',
#  'living area',
#  'area work',
#  'work desk',
#  'desk fitness',
#  'fitness center',
#  'center free',
#  'free weights',
#  'weights weight',
#  'weight machines',
#  'machines two',
#  'two rows',
#  'rows cardio',
#  'cardio equipment',
#  'equipment shared',
#  'shared room',
#  'room others',
#  'others feel',
#  'feel cramped',
#  'cramped way',
#  'way great',
#  'great property',
#  'property ',
#  'asked high',
#  'high floor',
#  'floor away',
#  'away elevator',
#  'elevator got',
#  'got room',
#  'room pleasantly',
#  'pleasantly decorated',
#  'decorated functional',
#  'functional clean',
#  'clean need',
#  'need whole',
#  'whole lot',
#  'lot service',
#  'service pleasant',
#  'pleasant prompt',
#  'prompt used',
#  'used fitness',
#  'fitness center',
#  'center well',
#  'well equipped',
#  'equipped everything',
#  'everything working',
#  'working order',
#  'order great',
#  'great location',
#  'location one',
#  'one end',
#  'end michigan',
#  'michigan avenue',
#  'avenue shopping',
#  'shopping district',
#  'district ',
#  'stayed conrad',
#  'conrad nights',
#  'nights thanksgiving',
#  'thanksgiving corner',
#  'corner room',
#  'room overlooking',
#  'overlooking n',
#  'n michigan',
#  'michigan av',
#  'av tribune',
#  'tribune building',
#  'building say',
#  'say star',
#  'star hotel',
#  'hotel damn',
#  'damn place',
#  'place faint',
#  'faint praise',
#  'praise wonderful',
#  'wonderful staff',
#  'staff unbelievably',
#  'unbelievably helpful',
#  'helpful standard',
#  'standard room',
#  'room superb',
#  'superb hd',
#  'hd plasma',
#  'plasma screens',
#  'screens luxury',
#  'luxury bedlinens',
#  'bedlinens ipod',
#  'ipod radio',
#  'radio huge',
#  'huge bathroom',
#  'bathroom location',
#  'location unbeatable',
#  'unbeatable right',
#  'right heart',
#  'heart everything',
#  'everything watched',
#  'watched whole',
#  'whole light',
#  'light festival',
#  'festival parade',
#  'parade window',
#  'window breakfasts',
#  'breakfasts excellent',
#  'excellent help',
#  'help buffet',
#  'buffet full',
#  'full attentive',
#  'attentive table',
#  'table service',
#  'service would',
#  'would hesitation',
#  'hesitation recommending',
#  'recommending staying',
#  'staying hotel',
#  'hotel ',
#  'got back',
#  'back days',
#  'days chicago',
#  'chicago shopping',
#  'shopping girlfriends',
#  'girlfriends first',
#  'first time',
#  'time stayed',
#  'stayed omni',
#  'omni saw',
#  'saw rate',
#  'rate included',
#  'included free',
#  'free food',
#  'food travelzoo',
#  'travelzoo three',
#  'three us',
#  'us year',
#  'year olds',
#  'olds stayed',
#  'stayed one',
#  'one suite',
#  'suite double',
#  'double beds',
#  'beds comfortable',
#  'comfortable pull',
#  'pull sofa',
#  'sofa plenty',
#  'plenty room',
#  'room food',
#  'food restaurant',
#  'restaurant great',
#  'great service',
#  'service outstanding',
#  'outstanding everone',
#  'everone came',
#  'came contact',
#  'contact early',
#  'early morning',
#  'morning delivery',
#  'delivery free',
#  'free coffee',
#  'coffee juice',
#  'juice hot',
#  'hot chocolate',
#  'chocolate fabulous',
#  'fabulous recommendations',
#  'recommendations staff',
#  'staff eat',
#  'eat time',
#  'time movies',
#  'movies shopping',
#  'shopping areas',
#  'areas etc',
#  'etc really',
#  'really helpful',
#  'helpful need',
#  'need mention',
#  'mention outstanding',
#  'outstanding location',
#  'location simply',
#  'simply best',
#  'best decided',
#  'decided omni',
#  'omni new',
#  'new favorite',
#  'favorite hotel',
#  'hotel ',
#  'arrived omni',
#  'omni nd',
#  'nd september',
#  'september day',
#  'day stay',
#  'stay took',
#  'took ill',
#  'ill left',
#  'left plane',
#  'plane travelling',
#  'travelling manchester',
#  'manchester saw',
#  'saw room',
#  'room anticipated',
#  'anticipated go',
#  'go days',
#  'days room',
#  'room spacious',
#  'spacious clean',
#  'clean bed',
#  'bed extremely',
#  'extremely comfortable',
#  'comfortable bathroom',
#  'bathroom large',
#  'large clean',
#  'clean could',
#  'could ask',
#  'ask coffee',
#  'coffee juice',
#  'juice left',
#  'left outside',
#  'outside door',
#  'door every',
#  'every morning',
#  'morning time',
#  'time requested',
#  'requested managed',
#  'managed go',
#  'go th',
#  'th floor',
#  'floor see',
#  'see sun',
#  'sun terrace',
#  'terrace outside',
#  'outside gym',
#  'gym sun',
#  'sun terrace',
#  'terrace city',
#  'city hotel',
#  'hotel great',
#  'great idea',
#  'idea terrace',
#  'terrace bit',
#  'bit grim',
#  'grim sunbeds',
#  'sunbeds concrete',
#  'concrete floor',
#  'floor also',
#  'also noise',
#  'noise air',
#  'air conditioning',
#  'conditioning unit',
#  'unit could',
#  'could bit',
#  'bit cheering',
#  'cheering saw',
#  'saw chicago',
#  'chicago pleasing',
#  'pleasing something',
#  'something everyone',
#  'everyone would',
#  'would go',
#  'go back',
#  'back omni',
#  'omni yes',
#  'yes would',
#  'would ',
#  'visit chicago',
#  'chicago chose',
#  'chose hyatt',
#  'hyatt due',
#  'due location',
#  'location downtown',
#  'downtown within',
#  'within walking',
#  'walking distance',
#  'distance major',
#  'major attractions',
#  'attractions sears',
#  'sears tower',
#  'tower magnificent',
#  'magnificent mile',
#  'mile grant',
#  'grant millenium',
#  'millenium parks',
#  'parks etc',
#  'etc subway',
#  'subway bus',
#  'bus stops',
#  'stops close',
#  'close travel',
#  'travel locations',
#  'locations city',
#  'city overall',
#  'overall hotel',
#  'hotel nice',
#  'nice clean',
#  'clean great',
#  'great location',
#  'location safe',
#  'safe area',
#  'area went',
#  'went beautiful',
#  'beautiful wrigley',
#  'wrigley field',
#  'field soldier',
#  'soldier field',
#  'field saw',
#  'saw teams',
#  'teams play',
#  'play love',
#  'love chicago',
#  'chicago would',
#  'would defenitely',
#  'defenitely stay',
#  'stay ',
#  'stayed fairmont',
#  'fairmont chicago',
#  'chicago one',
#  'one night',
#  'night frequent',
#  'frequent business',
#  'business traveler',
#  'traveler familiar',
#  'familiar travel',
#  'travel rituals',
#  'rituals checked',
#  'checked late',
#  'late almost',
#  'almost pm',
#  'pm due',
#  'due flight',
#  'flight cancellations',
#  'cancellations home',
#  'home airport',
#  'airport atlanta',
#  'atlanta took',
#  'took shuttle',
#  'shuttle airport',
#  'airport best',
#  'best option',
#  'option lieu',
#  'lieu priced',
#  'priced taxis',
#  'taxis first',
#  'first time',
#  'time staying',
#  'staying hotel',
#  'hotel upon',
#  'upon arrival',
#  'arrival immediately',
#  'immediately noticed',
#  'noticed entrance',
#  'entrance appeared',
#  'appeared welcoming',
#  'welcoming warm',
#  'warm checked',
#  'checked problems',
#  'problems desk',
#  'desk person',
#  'person even',
#  'even asked',
#  'asked prefer',
#  'prefer king',
#  'king double',
#  'double reconfirming',
#  'reconfirming reservation',
#  'reservation preference',
#  'preference always',
#  'always take',
#  'take king',
#  'king bed',
#  'bed fantastic',
#  'fantastic suited',
#  'suited great',
#  'great linen',
#  'linen incredible',
#  'incredible feather',
#  'feather pillows',
#  'pillows named',
#  'named encompass',
#  'encompass made',
#  'made pillow',
#  'pillow factory',
#  'factory checked',
#  'checked tags',
#  'tags since',
#  'since plan',
#  'plan buy',
#  'buy ate',
#  'ate dinner',
#  'dinner hotel',
#  'hotel restaurant',
#  'restaurant aria',
#  'aria mention',
#  'mention like',
#  'like considered',
#  'considered separate',
#  'separate hotel',
#  'hotel yes',
#  'yes stand',
#  'stand food',
#  'food asian',
#  'asian fusion',
#  'fusion truly',
#  'truly wonderful',
#  'wonderful gourmand',
#  'gourmand life',
#  'life long',
#  'long foodie',
#  'foodie appreciate',
#  'appreciate great',
#  'great food',
#  'food taste',
#  'taste hotel',
#  'hotel service',
#  'service good',
#  'good well',
#  'well drawback',
#  'drawback breakfast',
#  'breakfast buffet',
#  'buffet restaurant',
#  'restaurant seems',
#  'seems need',
#  'need stick',
#  'stick dinner',
#  'dinner theme',
#  'theme solely',
#  'solely missed',
#  'missed mark',
#  'mark relatively',
#  'relatively simply',
#  'simply things',
#  'things like',
#  'like scrambled',
#  'scrambled eggs',
#  'eggs buffet',
#  'buffet tasted',
#  'tasted bit',
#  'bit metallic',
#  'metallic made',
#  'made getting',
#  'getting special',
#  'special order',
#  'order made',
#  'made immediately',
#  'immediately passed',
#  'passed buffet',
#  'buffet would',
#  'would highly',
#  'highly recommend',
#  'recommend hotel',
#  'hotel atmosphere',
#  'atmosphere great',
#  'great view',
#  'view get',
#  'get room',
#  'room one',
#  'one fabulous',
#  'fabulous dinner',
#  'dinner pass',
#  'pass breakfast',
#  'breakfast buffet',
#  'buffet ',
#  'ok first',
#  'first trip',
#  'trip chicago',
#  'chicago litlle',
#  'litlle worried',
#  'worried hotel',
#  'hotel location',
#  'location finally',
#  'finally decided',
#  'decided conrad',
#  'conrad wath',
#  'wath good',
#  'good experience',
#  'experience booked',
#  'booked king',
#  'king deluxe',
#  'deluxe room',
#  'room th',
#  'th floor',
#  'floor view',
#  'view amazing',
#  'amazing coplaint',
#  'coplaint could',
#  'could room',
#  'room nice',
#  'nice bath',
#  'bath appliances',
#  'appliances good',
#  'good size',
#  'size good',
#  'good plasma',
#  'plasma tv',
#  'tv free',
#  'free internet',
#  'internet asked',
#  'asked one',
#  'one day',
#  'day breaksfast',
#  'breaksfast amazing',
#  'amazing food',
#  'food overall',
#  'overall price',
#  'price aroufn',
#  'aroufn great',
#  'great surprise',
#  'surprise locating',
#  'locating good',
#  'good blocks',
#  'blocks everything',
#  'everything quiet',
#  'quiet hotel',
#  'hotel ',
#  'arrived friday',
#  'friday room',
#  'room ready',
#  'ready us',
#  'us mind',
#  'mind check',
#  'check pm',
#  'pm got',
#  'got room',
#  'room priceline',
#  'priceline per',
#  'per night',
#  'night stayed',
#  'stayed nights',
#  'nights upgraded',
#  'upgraded free',
#  'free suite',
#  'suite think',
#  'think blown',
#  'blown away',
#  'away forgot',
#  'forgot thank',
#  'thank check',
#  'check room',
#  'room fantastic',
#  'fantastic also',
#  'also wet',
#  'wet bar',
#  'bar fridge',
#  'fridge bathroom',
#  'bathroom quite',
#  'quite large',
#  'large nice',
#  'nice sized',
#  'sized closet',
#  'closet many',
#  'many hangers',
#  'hangers knew',
#  'knew previous',
#  'previous reviews',
#  'reviews touch',
#  'touch mini',
#  'mini bar',
#  'bar bed',
#  'bed pillows',
#  'pillows comfortable',
#  'comfortable room',
#  'room clean',
#  'clean every',
#  'every employee',
#  'employee went',
#  'went way',
#  'way friendly',
#  'friendly helpful',
#  'helpful stayed',
#  'stayed th',
#  'th floor',
#  'floor east',
#  'east tower',
#  'tower quiet',
#  'quiet room',
#  'room yes',
#  'yes could',
#  'could hear',
#  'hear people',
#  'people hallways',
#  'hallways rude',
#  'rude yelling',
#  'yelling children',
#  'children adults',
#  'adults know',
#  'know everyone',
#  'everyone complains',
#  'complains parking',
#  'parking chicago',
#  'chicago every',
#  'every hotel',
#  'hotel saw',
#  'saw charged',
#  'charged much',
#  'much without',
#  'without privledges',
#  'privledges use',
#  'use restaurants',
#  'restaurants health',
#  'health club',
#  'club tried',
#  'tried eat',
#  'eat corner',
#  'corner bakery',
#  'bakery crowded',
#  'crowded breakfast',
#  'breakfast nearby',
#  'nearby houlihan',
#  'houlihan buffet',
#  'buffet per',
#  'per person',
#  'person also',
#  'also grocery',
#  'grocery store',
#  'store behind',
#  'behind hotel',
#  'hotel great',
#  'great far',
#  'far away',
#  'away know',
#  'know many',
#  'many bad',
#  'bad reviews',
#  'reviews hotel',
#  'hotel yes',
#  'yes big',
#  'big hotel',
#  'hotel want',
#  'want busy',
#  'busy lobby',
#  'lobby stay',
#  'stay plus',
#  'plus room',
#  'room hotel',
#  'hotel loved',
#  'loved hotel',
#  'hotel would',
#  'would recommend',
#  'recommend anyone',
#  'anyone one',
#  'one problem',
#  'problem busy',
#  'busy would',
#  'would stay',
#  'stay heartbeat',
#  'heartbeat ',
#  'wife came',
#  'came spend',
#  'spend weekend',
#  'weekend downtown',
#  'downtown chicago',
#  'chicago shopping',
#  'shopping found',
#  'found conrad',
#  'conrad hotel',
#  'hotel well',
#  'well located',
#  'located close',
#  'close everything',
#  'everything downtown',
#  'downtown size',
#  'size make',
#  'make feel',
#  'feel lost',
#  'lost convention',
#  'convention world',
#  'world feeling',
#  'feeling staying',
#  'staying larger',
#  'larger hotels',
#  'hotels past',
#  'past suite',
#  'suite view',
#  'view michigan',
#  'michigan avenue',
#  'avenue bit',
#  'bit lake',
#  'lake end',
#  'end staff',
#  'staff professional',
#  'professional pleasant',
#  'pleasant friendly',
#  'friendly making',
#  'making us',
#  'us feel',
#  'feel comfortable',
#  'comfortable internet',
#  'internet free',
#  'free n',
#  'n rooms',
#  'rooms making',
#  'making review',
#  'review ',
#  'got sunday',
#  'sunday night',
#  'night stay',
#  'stay priceline',
#  'priceline com',
#  'com would',
#  'would hard',
#  'hard complain',
#  'complain truly',
#  'truly great',
#  'great hotel',
#  'hotel even',
#  'even paid',
#  'paid double',
#  'double first',
#  'first impression',
#  'impression get',
#  'get walk',
#  'walk sliding',
#  'sliding doors',
#  'doors hyatt',
#  'hyatt regency',
#  'regency chicago',
#  'chicago wow',
#  'wow lobby',
#  'lobby beautiful',
#  'beautiful upscale',
#  'upscale mall',
#  'mall type',
#  'type look',
#  'look open',
#  'open area',
#  'area restaurant',
#  'restaurant plenty',
#  'plenty couches',
#  'couches seats',
#  'seats etc',
#  'etc people',
#  'people watch',
#  'watch lake',
#  'lake water',
#  'water fountains',
#  'fountains take',
#  'take escalator',
#  'escalator concierge',
#  'concierge directory',
#  'directory check',
#  'check area',
#  'area hotel',
#  'hotel let',
#  'let check',
#  'check pm',
#  'pm pm',
#  'pm check',
#  'check time',
#  'time suggest',
#  'suggest call',
#  'call ahead',
#  'ahead like',
#  'like know',
#  'know coming',
#  'coming early',
#  'early women',
#  'women desk',
#  'desk friendly',
#  'friendly requested',
#  'requested higher',
#  'higher level',
#  'level floor',
#  'floor happy',
#  'happy look',
#  'look even',
#  'even told',
#  'told room',
#  'room th',
#  'th floor',
#  'floor veiw',
#  'veiw river',
#  'river go',
#  'go higher',
#  'higher view',
#  'view thought',
#  'thought pretty',
#  'pretty nice',
#  'nice give',
#  'give information',
#  'information wouldnt',
#  'wouldnt get',
#  'get stuck',
#  'stuck room',
#  'room view',
#  'view wall',
#  'wall rooms',
#  'rooms big',
#  'big doubles',
#  'doubles room',
#  'room beds',
#  'beds beautiful',
#  'beautiful great',
#  'great pillows',
#  'pillows blankets',
#  'blankets headboards',
#  'headboards etc',
#  'etc ipod',
#  'ipod alarm',
#  'alarm clock',
#  'clock nice',
#  'nice st',
#  'st century',
#  'century touch',
#  'touch room',
#  ...]

# %%
def laplace_smoothening(word,c):
    if(c):
        numerator = truthful_token_count[word] + 1
        denominator = sum(truthful_token_count.values()) + len(vocab)
        return math.log(numerator/denominator)
    else:
        numerator = deceptive_token_count[word] + 1
        denominator = sum(truthful_token_count.values()) + len(vocab)
        return math.log(numerator/denominator)

# %%
def predict(reviews):
    predicted_classes = []
    for review in reviews:
        
        class_scores = [deceptive_prior_log_prob,truthful_prior_log_prob]
        words = word_tokenize(review)
        for word in words:
            if word not in vocab:
                continue
            
            for c in range(2):
                log_w_give_c = laplace_smoothening(word,c)
                class_scores[c] += log_w_give_c
        
        predicted_classes.append(class_scores.index(max(class_scores)))  
    return predicted_classes

# %%
def addLabel(value):
    if(value == "truthful"):
        return 1
    else:
        return 0

test_df['label'] = test_df['deceptive'].apply(addLabel)

# %%
true_classes = list(test_df.label)

# %%
predicted_classes = predict(test_df.text)

# %%
count = 0
for i in range(len(true_classes)):
    if true_classes[i] == predicted_classes[i]:
        count += 1
count/len(true_classes)
# Out:
# 0.47291666666666665

# %%
truePositive = trueNegative = falsePositive = falseNegative = 0

# %%
for i in range(len(true_classes)):
    if(true_classes[i] == predicted_classes[i] == 0):
        truePositive += 1
    elif true_classes[i] == predicted_classes[i] == 1:
        trueNegative += 1
    elif true_classes[i] == 1 and predicted_classes[i] == 0:
        falsePositive += 1
    elif true_classes[i] == 0 and predicted_classes[i] == 1 :
        falseNegative += 1

# %%
accuracy = (truePositive + trueNegative)/(truePositive + trueNegative + falsePositive + falseNegative)
precision = truePositive/(truePositive + falsePositive)
recall =truePositive/(truePositive + falseNegative) 

accuracy,precision,recall
# Out:
# (0.5041666666666667, 0.5041666666666667, 1.0)
